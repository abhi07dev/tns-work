# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi07dev/tns-work/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/content/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df['sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
df['sex'] = df['sex'].replace('male', 1).replace('female',0)
df['smoker'] = df['smoker'].replace('yes',1).replace('no',0)
df['region'] = df['region'].replace('southwest', 0).replace('southeast',1).replace('northwest', 5).replace('northwest', 6)
# Out:
# /tmp/ipykernel_10354/3675684012.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['region'] = df['region'].replace('southwest', 0).replace('southeast',1).replace('northwest', 5).replace('northwest', 6)

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       0  16884.92400
# 1   18    1  33.770         1       0       1   1725.55230
# 2   28    1  33.000         3       0       1   4449.46200
# 3   33    1  22.705         0       0       5  21984.47061
# 4   32    1  28.880         0       0       5   3866.85520

# %%
df['bmi'] = np.std(df['bmi'])

# %%
df.head()
# Out:
#    age  sex       bmi  children  smoker  region      charges
# 0   19    0  6.095908         0       1       0  16884.92400
# 1   18    1  6.095908         1       0       1   1725.55230
# 2   28    1  6.095908         3       0       1   4449.46200
# 3   33    1  6.095908         0       0       5  21984.47061
# 4   32    1  6.095908         0       0       5   3866.85520

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
feature = ['age', 'sex', 'bmi', 'children', 'smoker', 'region']
x = ['region']
y = ['charges']

# %%
print(y)
# Out:
# ['charges']
